# %%
import pandas as pd
import matplotlib.pyplot as plt

data_source = pd.read_excel('figure6.xlsx')
# 函数plot()尝试根据数字绘制出有意义的图形
#print(data_source['Susceptible(EB)'])

figsize = 5,4
figure, ax = plt.subplots(figsize=figsize)
plt.plot(data_source['Susceptible(EB)'],'-r',label='Susceptible(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Exposed(EB)'],'b-',label='Exposed(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Symptomatic(EB)'],'-g',label='Symptomatic(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Asymptomatic(EB)'],'-o',label='Asymptomatic(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Recovered(EB)'],'-y',label='Recovered(EB)',linewidth=2.0,ms=1)
plt.axis([0,100,0,1])
plt.title('The Results of Equation-based Model(fraction of population)',font1)
# 设置x轴名称
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 10,
}
plt.grid(linestyle="--")  # 设置背景网格线为虚线
#设置图例
plt.legend(loc=0, numpoints=1,prop=font1)
plt.xlabel("Days",font1)
# 设置y轴名称
plt.ylabel("Fraction of Initial Population",font1)
#保存图片
plt.tick_params(labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]
plt.savefig('F:/要多写多发期刊论文啊/社区防疫 论文/做工大的吧/纯ABS要能跑出来我去死/格式冲冲冲/图重新绘制/figure6-1.png',bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_source = pd.read_excel('figure6.xlsx')
# 函数plot()尝试根据数字绘制出有意义的图形
figsize = 5,4
figure, ax = plt.subplots(figsize=figsize)
plt.plot(data_source['Susceptible(ABS)'],'-r',label='Susceptible(ABS)',linewidth=2.0,ms=1)
plt.plot(data_source['Exposed(ABS)'],'b-',label='Exposed(ABS)',linewidth=2.0,ms=1)
plt.plot(data_source['Symptomatic(ABS)'],'-g',label='Symptomatic(ABS)',linewidth=2.0,ms=1)
plt.plot(data_source['Asymptomatic(ABS)'],'-o',label='Asymptomatic(ABS)',linewidth=2.0,ms=1)
plt.plot(data_source['Recovered(ABS)'],'-y',label='Recovered(ABS)',linewidth=2.0,ms=1)
plt.axis([0,100,0,1])
plt.title('The Results of ABS Model(fraction of population)',font1)
# 设置x轴名称
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 10,
}
plt.grid(linestyle="--")  # 设置背景网格线为虚线
#设置图例
plt.legend(loc=0, numpoints=1,prop=font1)
plt.xlabel("Days",font1)
# 设置y轴名称
plt.ylabel("Fraction of Initial Population",font1)
plt.tick_params(labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]
#保存图片
plt.savefig('F:/要多写多发期刊论文啊/社区防疫 论文/做工大的吧/纯ABS要能跑出来我去死/格式冲冲冲/图重新绘制/figure6-2.png',bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_source = pd.read_excel('figure6.xlsx')
# 函数plot()尝试根据数字绘制出有意义的图形
#print(data_source['Susceptible(EB)'])

figsize = 5,4
figure, ax = plt.subplots(figsize=figsize)
plt.plot(data_source['Susceptible(EB)'],'-r',label='Susceptible(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Exposed(EB)'],'b-',label='Exposed(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Symptomatic(EB)'],'-g',label='Symptomatic(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Asymptomatic(EB)'],'-o',label='Asymptomatic(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Recovered(EB)'],'-y',label='Recovered(EB)',linewidth=2.0,ms=1)
plt.plot(data_source['Susceptible(ABS)'],'-r',label='Susceptible(ABS)',linewidth=2.0,ms=1,linestyle='--')
plt.plot(data_source['Exposed(ABS)'],'b-',label='Exposed(ABS)',linewidth=2.0,ms=1,linestyle='--')
plt.plot(data_source['Symptomatic(ABS)'],'-g',label='Symptomatic(ABS)',linewidth=2.0,ms=1,linestyle='--')
plt.plot(data_source['Asymptomatic(ABS)'],'-o',label='Asymptomatic(ABS)',linewidth=2.0,ms=1,linestyle='--')
plt.plot(data_source['Recovered(ABS)'],'-y',label='Recovered(ABS)',linewidth=2.0,ms=1,linestyle='--')
plt.axis([0,100,0,1])
# 设置x轴名称
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 10,
}
plt.title('The Results of EBM And ABM(taking fraction of population as standard of comparison)',font1)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
#设置图例
plt.legend(loc=0, numpoints=1,prop=font1)
plt.xlabel("Days",font1)
# 设置y轴名称
plt.ylabel("Fraction of Initial Population",font1)
#保存图片
plt.tick_params(labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]
plt.savefig('F:/要多写多发期刊论文啊/社区防疫 论文/做工大的吧/纯ABS要能跑出来我去死/格式冲冲冲/图重新绘制/figure6-3.png',bbox_inches='tight')
